trans = '332	372	368	387	404	429	484	561	616	636	682	758	854	930	1013	1100	1226	1365	1564	1689	1835	1983	2174	2410	3044	3432	4071	4434	5160	5682	6061	7501	9097	10692	12048	14182	16750	20184	23829	27789	32696	38551	46412	55515	65954	75974	90104	105591	122628	137657	152465	167939	184338	215341	250417	279677	323032	366797	415448	471391	529158	614707	708830	12	-1.1	5	4.5	6.1	12.9	15.9	9.9	3.3	7.2	11.1	12.7	8.9	8.9	8.6	11.4	11.4	14.6	8	8.7	8	9.6	10.9	26.3	12.7	18.6	8.9	16.4	10.1	6.7	23.7	21.3	17.5	12.7	17.7	18.1	20.5	18.1	16.6	17.7	17.9	20.4	19.6	18.8	15.2	18.6	17.2	16.1	12.3	10.8	10.1	9.8	16.8	16.3	11.7	15.5	13.5	13.3	13.5	12.3	16.2	15.3'
trans = trans.split('	')
bank = '86	98	86	98	98	111	135	148	159	173	196	226	278	307	360	426	465	535	587	661	792	930	1070	1330	1665	2146	2542	2809	3052	3387	4116	5230	6033	6634	7760	8824	10050	11531	13762	17212	20611	28080	29164	38246	45488	60616	66262	76825	88271	108586	108243	127580	147175	165049	171098	184118	217196	251195	298931	331793	410407	481495	549500	14.8	-12.9	14.8	0	12.9	21.9	9.4	7.9	8.6	13.4	15.1	22.9	10.6	17.2	18.2	9.2	15.2	9.7	12.6	19.8	17.5	15	24.3	25.3	28.9	18.5	10.5	8.6	11	21.5	27.1	15.3	10	17	13.7	13.9	14.7	19.3	25.1	19.8	36.2	3.9	31.1	18.9	33.3	9.3	15.9	14.9	23	-0.3	17.9	15.4	12.1	3.7	7.6	18	15.7	19	11	23.7	17.3	14.1'
bank = bank.split('	')

# %%
agri = np.array([float(a) for a in agri])
elec = np.array([float(a) for a in elec])
comm = np.array([float(a) for a in comm])
trans = np.array([float(a) for a in trans])
bank = np.array([float(a) for a in bank])

print(len(agri), len(elec), len(comm), len(trans), len(bank))

years = 'GDP at Current Prices (in Crore) - 1950-51	GDP at Current Prices (in Crore) - 1951-52	GDP at Current Prices (in Crore) - 1952-53	GDP at Current Prices (in Crore) - 1953-54	GDP at Current Prices (in Crore) - 1954-55	GDP at Current Prices (in Crore) - 1955-56	GDP at Current Prices (in Crore) - 1956-57	GDP at Current Prices (in Crore) - 1957-58	GDP at Current Prices (in Crore) - 1958-59	GDP at Current Prices (in Crore) - 1959-60	GDP at Current Prices (in Crore) - 1960-61	GDP at Current Prices (in Crore) - 1961-62	GDP at Current Prices (in Crore) - 1962-63	GDP at Current Prices (in Crore) - 1963-64	GDP at Current Prices (in Crore) - 1964-65	GDP at Current Prices (in Crore) - 1965-66	GDP at Current Prices (in Crore) - 1966-67	GDP at Current Prices (in Crore) - 1967-68	GDP at Current Prices (in Crore) - 1968-69	GDP at Current Prices (in Crore) - 1969-70	GDP at Current Prices (in Crore) - 1970-71	GDP at Current Prices (in Crore) - 1971-72	GDP at Current Prices (in Crore) - 1972-73	GDP at Current Prices (in Crore) - 1973-74	GDP at Current Prices (in Crore) - 1974-75	GDP at Current Prices (in Crore) - 1975-76	GDP at Current Prices (in Crore) - 1976-77	GDP at Current Prices (in Crore) - 1977-78	GDP at Current Prices (in Crore) - 1978-79	GDP at Current Prices (in Crore) - 1979-80	GDP at Current Prices (in Crore) - 1980-81	GDP at Current Pr
ices - Growth Rate - 1984-85	GDP at Current Prices - Growth Rate - 1985-86	GDP at Current Prices - Growth Rate - 1986-87	GDP at Current Prices - Growth Rate - 1987-88	GDP at Current Prices - Growth Rate - 1988-89	GDP at Current Prices - Growth Rate - 1989-90	GDP at Current Prices - Growth Rate - 1990-91	GDP at Current Prices - Growth Rate - 1991-92	GDP at Current Prices - Growth Rate - 1992-93	GDP at Current Prices - Growth Rate - 1993-94	GDP at Current Prices - Growth Rate - 1994-95	GDP at Current Prices - Growth Rate - 1995-96	GDP at Current Prices - Growth Rate - 1996-97	GDP at Current Prices - Growth Rate - 1997-98	GDP at Current Prices - Growth Rate - 1998-99	GDP at Current Prices - Growth Rate - 1999-00	GDP at Current Prices - Growth Rate - 2000-01	GDP at Current Prices - Growth Rate - 2001-02	GDP at Current Prices - Growth Rate - 2002-03	GDP at Current Prices - Growth Rate - 2003-04	GDP at Current Prices - Growth Rate - 2004-05	GDP at Current Prices - Growth Rate - 2005-06	GDP at Current Prices - Growth Rate - 2006-07	GDP at Current Prices - Growth Rate - 2007-08	GDP at Current Prices - Growth Rate - 2008-09	GDP at Current Prices - Growth Rate - 2009-10	GDP at Current Prices - Growth Rate - 2010-11	GDP at Current Prices - Growth Rate - 2011-12	GDP at Current Prices - Growth Rate - 2012-13	GDP at Current Prices - Growth Rate - 2013-14(PE)'
years = np.array([int(g.split('-')[-2]) for g in years.split('	')])
# Out:
# 127 127 125 125 125

# %% [markdown]
# ### GDP from different sectors since 1950

# %%
plt.scatter(years[:63], trans[:63], s=8, label='Transport')
plt.scatter(years[:63], agri[:63], s=8, label='Agriculture')
plt.scatter(years[:63], elec[:63], s=8, label='Electricity')
plt.scatter(years[:63], bank[:63], s=8, label='Bank')
plt.scatter(years[:63], comm[:63], s=8, label='Communication')
plt.title('GDP from different sectors')
plt.xlabel('Year')
plt.ylabel('GDP (in million crore rupees)')
plt.legend()

# %% [markdown]
# ### GDP Growth in different sectors between 2003-12

# %%
w = 0.1
fig = plt.figure(figsize=(15, 7))
plt.bar(years[-11:-1]-w, trans[-10:], width=w, label='Transport')
plt.bar(years[-11:-1]-2*w, agri[-11:-1], width=w, label='Agriculture')
plt.bar(years[-11:-1], elec[-11:-1], width=w, label='Electricity')
plt.bar(years[-11:-1]+w, bank[-10:], width=w, label='Bank')
plt.bar(years[-11:-1]+2*w, comm[-10:], width=w, label='Communication')
plt.title('% GDP Growth in different sectors between 2003-12')
plt.xlabel('Year')
plt.xticks(years[-11:-1])
plt.ylabel('% GDP Growth')
plt.legend()

# %% [markdown]
# ### Sectorwise %GDP Growth since 1950

# %%
plt.boxplot([comm[63:], agri[64:], elec[64:],  bank[64:], trans[64:]],\
            labels=['Communication','Agriculture', 'Electricity', 'Bank', 'Transport'])
plt.ylabel('% GDP Growth')
plt.xlabel('Sector')
plt.title('% GDP Growth in different sectors since 1950')
# Out:
# Text(0.5, 1.0, '% GDP Growth in different sectors since 1950')
